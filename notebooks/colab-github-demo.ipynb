# %% [markdown]
# <a href="https://colab.research.google.com/github/deepvirk7/SELF_LEARNING-DAILY-MCQ-S-/blob/main/notebooks/colab-github-demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PYTHON ASSIGNMENT

# %% [markdown]
# 1.![image.png](data:image/png;base64,...)

# %%
L=[11,12,13,14]
print("ORIGINAL LIST",L)
L.append(50)
print("list after adding 50" ,L)
L.append(60)
print("list after adding 60" ,L)
# Out:
# ORIGINAL LIST [11, 12, 13, 14]
# list after adding 50 [11, 12, 13, 14, 50]
# list after adding 60 [11, 12, 13, 14, 50, 60]

# %%
L=[11, 12, 13, 14, 50, 60]
print("ORIGINAL LIST ",L)
del L[1]
print("list after deleting 12",L)
del L[1]
print("list after deleting 13",L)
# Out:
# ORIGINAL LIST  [11, 12, 13, 14, 50, 60]
# list after deleting 12 [11, 13, 14, 50, 60]
# list after deleting 13 [11, 14, 50, 60]

# %%
L=[11, 12, 13, 14, 50, 60]
print("original list",L)
L.sort()
print("sorted list: ",L)
# Out:
# original list [11, 12, 13, 14, 50, 60]
# sorted list:  [11, 12, 13, 14, 50, 60]

# %%
L=[11, 12, 13, 14, 50, 60]
L.sort(reverse=True)
print("SORTED LIST IN DESCENDING ORDER :",L)
# Out:
# SORTED LIST IN DESCENDING ORDER : [60, 50, 14, 13, 12, 11]

# %%
L=[11, 12, 13, 14, 50, 60]
print ("Original List ;",L)


if (13 in L) == True:
	print ("Present")
else:
	print ("Not Present")
# Out:
# Original List ; [11, 12, 13, 14, 50, 60]
# Present

# %%
L=[11, 12, 13, 14, 50, 60]
print ("Original List ;",L)
print("NUMBER OF ELEMENTS IN LIST ",len(L))
# Out:
# Original List ; [11, 12, 13, 14, 50, 60]
# NUMBER OF ELEMENTS IN LIST  6

# %%
L=[11, 12, 13, 14, 50, 60]
print ("Original List ;",L)
sum_list=sum(L)
print("sum of elements of list :" ,sum_list)
# Out:
# sum of elements of list : 160

# %%
L=[11, 12, 13, 14, 50, 60]
print ("Original List ;",L)
odd_sum = sum(i for i in L if i % 2 != 0)
print("sum of odd numbers ",odd_sum)
# Out:
# Original List ; [11, 12, 13, 14, 50, 60]
# sum of odd numbers  24

# %%
L=[11, 12, 13, 14, 50, 60]
print ("Original List ;",L)
even_sum = sum(i for i in L if i % 2 == 0)
print("sum of even numbers ",even_sum)
# Out:
# Original List ; [11, 12, 13, 14, 50, 60]
# sum of even numbers  136

# %%
L=[11, 12, 13, 14, 50, 60]
print ("Original List ;",L)
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

prime_sum = sum(i for i in L if is_prime(i))
print("sum of prime numbers",prime_sum)
# Out:
# Original List ; [11, 12, 13, 14, 50, 60]
# sum of prime numbers 24

# %%
L=[11, 12, 13, 14, 50, 60]
print ("Original List ;",L)
L.clear()
print("list after clearing elements ",L)
# Out:
# Original List ; [11, 12, 13, 14, 50, 60]
# list after clearing elements  []

# %%
L=[11, 12, 13, 14, 50, 60]
print ("Original List ;",L)
del(L)
print(L)
# Out:
# Original List ; [11, 12, 13, 14, 50, 60]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-119625594> in <cell line: 0>()
#       2 print ("Original List ;",L)
#       3 del(L)
# ----> 4 print(L)
#
# NameError: name 'L' is not defined
